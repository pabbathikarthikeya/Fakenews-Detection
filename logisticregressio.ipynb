# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("taweilo/loan-approval-classification-data")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 751k/751k [00:03<00:00, 223kB/s]
# Extracting files...
# Path to dataset files: C:\Users\pabba\.cache\kagglehub\datasets\taweilo\loan-approval-classification-data\versions\1

# %%
import pandas as pd
path='C:/Users/pabba/.cache/kagglehub/datasets/taweilo/loan-approval-classification-data/versions/1/loan_data.csv'
df=pd.read_csv(path)
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
df.columns
# Out:
# Index(['person_age', 'person_gender', 'person_education', 'person_income',
#        'person_emp_exp', 'person_home_ownership', 'loan_amnt', 'loan_intent',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length',
#        'credit_score', 'previous_loan_defaults_on_file', 'loan_status'],
#       dtype='object')

# %%
df=df.drop(columns=['person_gender','previous_loan_defaults_on_file'],axis=1)

# %%
df.head()
# Out:
#    person_age person_education  person_income  person_emp_exp  \
# 0        22.0           Master        71948.0               0
# 1        21.0      High School        12282.0               0
# 2        25.0      High School        12438.0               3
# 3        23.0         Bachelor        79753.0               0
# 4        24.0           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  loan_status
# 0                 0.49                         3.0           561            1
# ...

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler
labelcols=['person_home_ownership','loan_intent','person_education']
le=LabelEncoder()
for col in labelcols:
    df[col]=le.fit_transform(df[col])

# %%
df.head()
# Out:
#    person_age  person_education  person_income  person_emp_exp  \
# 0        22.0                 4        71948.0               0
# 1        21.0                 3        12282.0               0
# 2        25.0                 3        12438.0               3
# 3        23.0                 1        79753.0               0
# 4        24.0                 4        66135.0               1
#
#    person_home_ownership  loan_amnt  loan_intent  loan_int_rate  \
# 0                      3    35000.0            4          16.02
# 1                      2     1000.0            1          11.14
# 2                      0     5500.0            3          12.87
# 3                      3    35000.0            3          15.23
# 4                      3    35000.0            3          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  loan_status
# 0                 0.49                         3.0           561            1
# ...

# %%
df.isnull().sum()
# Out:
# person_age                    0
# person_education              0
# person_income                 0
# person_emp_exp                0
# person_home_ownership         0
# loan_amnt                     0
# loan_intent                   0
# loan_int_rate                 0
# loan_percent_income           0
# cb_person_cred_hist_length    0
# credit_score                  0
# loan_status                   0
# dtype: int64

# %%
x=df.iloc[:,:-1]
y=df['loan_status']

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression(max_iter=1000)
log.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred=log.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
print("Accuracy score:",accuracy_score(y_test,y_pred))
print("Confusion matrix:",confusion_matrix(y_test,y_pred))
print("Classification report:",classification_report(y_test,y_pred))
# Out:
# Accuracy score: 0.8325555555555556
# Confusion matrix: [[6617  373]
#  [1134  876]]
# Classification report:               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90      6990
#            1       0.70      0.44      0.54      2010
#
#     accuracy                           0.83      9000
#    macro avg       0.78      0.69      0.72      9000
# weighted avg       0.82      0.83      0.82      9000

# %%
# Example input: (use same order and encoding as training)
input_data = {
    'person_age': 27,
    'person_education': 'Bachelor',
    'person_income': 60000,
    'person_emp_exp': 2,
    'person_home_ownership': 'RENT',
    'loan_amnt': 15000,
    'loan_intent': 'PERSONAL',
    'loan_int_rate': 12.5,
    'loan_percent_income': 0.25,
    'cb_person_cred_hist_length': 3,
    'credit_score': 620
}

# %%
# Assuming label encoders from training phase
input_df = pd.DataFrame([input_data])

# Apply Label Encoding
input_df['person_home_ownership'] = le.fit_transform(input_df['person_home_ownership'])
input_df['loan_intent'] = le.fit_transform(input_df['loan_intent'])
input_df['person_education'] = le.fit_transform(input_df['person_education'])

# Apply Scaling
input_scaled = scaler.transform(input_df)

# Predict
prediction = log.predict(input_scaled)[0]
prediction_proba = log.predict_proba(input_scaled)[0]

# Output result
print("Loan Status Prediction:", "Approved (1)" if prediction == 1 else "Rejected (0)")
print(f"Confidence: {round(prediction_proba[prediction] * 100, 2)}%")
# Out:
# Loan Status Prediction: Rejected (0)
# Confidence: 57.5%

# %%
coeff=log.coef_[0]
coeff
# Out:
# array([ 1.03692955e-01,  1.23071130e-03,  3.81449109e-02, -7.59200926e-02,
#         4.41178476e-01, -5.39169381e-01, -2.54912285e-01,  9.79964143e-01,
#         1.26895122e+00, -1.41530419e-02, -2.06724304e-02])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


# 1. Get the coefficients from the trained model
coefficients = log.coef_[0]  # shape is (1, n_features), so take first row

# 2. Get the feature names (after encoding and dropping irrelevant columns)
feature_names = x.columns  # X is the final DataFrame used for training

# 3. Create a DataFrame for visualization
coef_df = pd.DataFrame({
    'Feature': feature_names,
    'Coefficient': coefficients
})

# 4. Sort by absolute value to see strongest effects
coef_df['abs_coeff'] = coef_df['Coefficient'].abs()
coef_df_sorted = coef_df.sort_values(by='abs_coeff', ascending=False)

# 5. Plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Coefficient', y='Feature', data=coef_df_sorted)
plt.title("Feature Importance in Logistic Regression")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 11
#       8 coefficients = log.coef_[0]  # shape is (1, n_features), so take first row
#      10 # 2. Get the feature names (after encoding and dropping irrelevant columns)
# ---> 11 feature_names = x.columns  # X is the final DataFrame used for training
#      13 # 3. Create a DataFrame for visualization
#      14 coef_df = pd.DataFrame({
#      15     'Feature': feature_names,
#      16     'Coefficient': coefficients
#      17 })
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
from sklearn.feature_extraction.text import TfidfTransformer,CountVectorizer
docs=['this is karthikeya currently in KL University']

countvectors=CountVectorizer()
wordcount=countvectors.fit_transform(docs)
print(wordcount.toarray())

tfidftransformer=TfidfTransformer()
tfidfmatrix=tfidftransformer.fit_transform(wordcount)

print(tfidfmatrix.toarray())
# Out:
# [[1 1 1 1 1 1 1]]
# [[0.37796447 0.37796447 0.37796447 0.37796447 0.37796447 0.37796447
#   0.37796447]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
docs=['this is karthikeya currently in KL University']

tfid=TfidfVectorizer()
tfidf=tfid.fit_transform(docs)

print(tfidf.toarray())
# Out:
# [[0.37796447 0.37796447 0.37796447 0.37796447 0.37796447 0.37796447
#   0.37796447]]
